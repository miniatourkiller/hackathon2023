# %%
import pandas as pd

pf = pd.read_csv('data (56).csv')
pf
# Out:
#                                  Unnamed: 0  \
# 0                      organisationunitname
# 1                  A.C.K Butonge Dispensary
# 2            Ace Africa (k) Wellness Centre
# 3          ACK Dr Pike Roper Medical Center
# 4    Aga Khan Health Service Bungoma Centre
# ..                                      ...
# 281                         Webuye Surgical
# 282          Wema Centre Medical Laboratory
# 283                 Western Family Hospital
# 284                   Weyeta Medical Clinic
# 285             Zion Medical Centre Bungoma
#
#                                          Unnamed: 1  \
# 0    September 2018 Currently on ART - below 1 year
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 281                                             NaN
# ...

# %%
pf.columns = pf.iloc[0]
pf
# Out:
# 0                      organisationunitname  \
# 0                      organisationunitname
# 1                  A.C.K Butonge Dispensary
# 2            Ace Africa (k) Wellness Centre
# 3          ACK Dr Pike Roper Medical Center
# 4    Aga Khan Health Service Bungoma Centre
# ..                                      ...
# 281                         Webuye Surgical
# 282          Wema Centre Medical Laboratory
# 283                 Western Family Hospital
# 284                   Weyeta Medical Clinic
# 285             Zion Medical Centre Bungoma
#
# 0    September 2018 Currently on ART - below 1 year  \
# 0    September 2018 Currently on ART - below 1 year
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 281                                             NaN
# ...

# %%
filtered = pf.drop(pf.index[0])
filtered
# Out:
# 0                      organisationunitname  \
# 1                  A.C.K Butonge Dispensary
# 2            Ace Africa (k) Wellness Centre
# 3          ACK Dr Pike Roper Medical Center
# 4    Aga Khan Health Service Bungoma Centre
# 5                    Almer Medical Services
# ..                                      ...
# 281                         Webuye Surgical
# 282          Wema Centre Medical Laboratory
# 283                 Western Family Hospital
# 284                   Weyeta Medical Clinic
# 285             Zion Medical Centre Bungoma
#
# 0   September 2018 Currently on ART - below 1 year  \
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# ..                                             ...
# 281                                            NaN
# ...

# %%
totalrows = filtered.shape[0]
totalrows
# Out:
# 285

# %%
column = pf['organisationunitname']
column
# Out:
# 0                        organisationunitname
# 1                    A.C.K Butonge Dispensary
# 2              Ace Africa (k) Wellness Centre
# 3            ACK Dr Pike Roper Medical Center
# 4      Aga Khan Health Service Bungoma Centre
#                         ...
# 281                           Webuye Surgical
# 282            Wema Centre Medical Laboratory
# 283                   Western Family Hospital
# 284                     Weyeta Medical Clinic
# 285               Zion Medical Centre Bungoma
# Name: organisationunitname, Length: 286, dtype: object

# %%
row = filtered.iloc[0]
row[0].split()
# Out:
# ['A.C.K', 'Butonge', 'Dispensary']

# %%
arrzero = []
for i in range(totalrows):
    rows = filtered.iloc[i]
    arrzero.append(rows[0])
arrzero
# Out:
# ['A.C.K Butonge Dispensary',
#  'Ace Africa (k) Wellness Centre',
#  'ACK Dr Pike Roper Medical Center',
#  'Aga Khan Health Service Bungoma Centre',
#  'Almer Medical Services',
#  'Alphine Health Care Medical Clinic',
#  'Ararat Medical Clinic',
#  'Bahai Dispensary',
#  'Balcurt Medical Clinic',
#  'Baptist Medical Center',
#  'Baptist Medical Center(Chwele)',
#  'Benglad Family Care Clinic',
#  'Bewa Medical clinic',
#  'Bisunu Dispensary',
#  'Bituyu Dispensary',
#  'Bliss GVS Health Care Kimilili',
#  'Bokoli Base Clinic',
#  'Bokoli Hospital',
#  'Brillian Doctors Plaza Hospital',
#  'Buckner Medical Clinic',
#  'Bukembe Dispensary',
#  'Bukokholo Dispensary',
#  'Bulondo Dispensary',
#  'Bumula Sub County Hospital',
#  'Bungoma Beyond Zero Mobile Unit',
#  "Bungoma Children's Clinic",
#  'Bungoma County Referral Hospital',
#  'Bungoma West Medical Services',
#  'Butieli Dispensary',
#  'Calvary Hope Medical Centre',
#  'Carmel Dispensary',
#  'Carmel Dispensary',
# ...

# %%
arr = []
arr2 = []
for i in range(totalrows):
    rows = filtered.iloc[i]
    arr2 = rows[0].split()
    for j in range(len(arr2)):
        if arr2[j].lower() != "ack" and arr2[j].lower() != "ace":
            arr.append(arr2[j].lower())
arr
# Out:
# ['a.c.k',
#  'butonge',
#  'dispensary',
#  'africa',
#  '(k)',
#  'wellness',
#  'centre',
#  'dr',
#  'pike',
#  'roper',
#  'medical',
#  'center',
#  'aga',
#  'khan',
#  'health',
#  'service',
#  'bungoma',
#  'centre',
#  'almer',
#  'medical',
#  'services',
#  'alphine',
#  'health',
#  'care',
#  'medical',
#  'clinic',
#  'ararat',
#  'medical',
#  'clinic',
#  'bahai',
#  'dispensary',
#  'balcurt',
#  'medical',
#  'clinic',
#  'baptist',
#  'medical',
#  'center',
#  'baptist',
#  'medical',
#  'center(chwele)',
#  'benglad',
#  'family',
#  'care',
#  'clinic',
#  'bewa',
#  'medical',
#  'clinic',
#  'bisunu',
#  'dispensary',
#  'bituyu',
#  'dispensary',
#  'bliss',
#  'gvs',
#  'health',
#  'care',
#  'kimilili',
#  'bokoli',
#  'base',
#  'clinic',
#  'bokoli',
#  'hospital',
#  'brillian',
#  'doctors',
#  'plaza',
#  'hospital',
#  'buckner',
#  'medical',
#  'clinic',
#  'bukembe',
#  'dispensary',
#  'bukokholo',
#  'dispensary',
#  'bulondo',
# ...

# %%
from spellchecker import SpellChecker
spell = SpellChecker()
spell.word_frequency.load_words(arrzero)
spell.word_frequency.load_words(arr)

# %%
spell.candidates("ack")
# Out:
# {'ack'}

# %%
name = "ack butonge dispensary"
arr3 = name.split()
suggestion =""
for i in range(len(arr3)):
    suggestion = suggestion+spell.correction(arr3[i])+" "
suggestion
# Out:
# 'ack butonge dispensary '
